# %%
import numpy as np
import pandas as pd
import pyarrow.parquet as pq
from pymongo import MongoClient
from datetime import datetime

# %%
# %pwd
# Out:
# 'C:\\Users\\user\\Desktop'

# %%
import os
os.getcwd()
path = "C:\\Users\\user\\Desktop\\data\\"

# %%
client = MongoClient("mongodb+srv://zelintian:tzl19970411@cluster0.gzafe90.mongodb.net/Uber_NYC")
db = client["Uber_NYC"]
collection = db["UberData"]

# %% [markdown]
# # read file name

# %%
file_name_list = []
for file_name in os.listdir(path):
    if '.parquet' in file_name:
        file_name_list.append(file_name)

# %%
file_name_list.sort()
file_name_list
# Out:
# ['fhvhv_tripdata_2021-01.parquet',
#  'fhvhv_tripdata_2021-02.parquet',
#  'fhvhv_tripdata_2021-03.parquet',
#  'fhvhv_tripdata_2021-04.parquet',
#  'fhvhv_tripdata_2021-05.parquet',
#  'fhvhv_tripdata_2021-06.parquet',
#  'fhvhv_tripdata_2021-07.parquet',
#  'fhvhv_tripdata_2021-08.parquet',
#  'fhvhv_tripdata_2021-09.parquet',
#  'fhvhv_tripdata_2021-10.parquet',
#  'fhvhv_tripdata_2021-11.parquet',
#  'fhvhv_tripdata_2021-12.parquet']

# %% [markdown]
# # send data

# %%
file_name = file_name_list[0]
file = pd.read_parquet(path + file_name)

# %%
file.columns
# Out:
# Index(['hvfhs_license_num', 'dispatching_base_num', 'originating_base_num',
#        'request_datetime', 'on_scene_datetime', 'pickup_datetime',
#        'dropoff_datetime', 'PULocationID', 'DOLocationID', 'trip_miles',
#        'trip_time', 'base_passenger_fare', 'tolls', 'bcf', 'sales_tax',
#        'congestion_surcharge', 'airport_fee', 'tips', 'driver_pay',
#        'shared_request_flag', 'shared_match_flag', 'access_a_ride_flag',
#        'wav_request_flag', 'wav_match_flag'],
#       dtype='object')

# %%
col_names = ['pickup_datetime', 'PULocationID', 'dropoff_datetime', 'DOLocationID']

# %%
file[col_names]
# Out:
#              pickup_datetime  PULocationID    dropoff_datetime  DOLocationID
# 0        2021-01-01 00:33:44           230 2021-01-01 00:49:07           166
# 1        2021-01-01 00:55:19           152 2021-01-01 01:18:21           167
# 2        2021-01-01 00:23:56           233 2021-01-01 00:38:05           142
# 3        2021-01-01 00:42:51           142 2021-01-01 00:45:50           143
# 4        2021-01-01 00:48:14           143 2021-01-01 01:08:42            78
# ...                      ...           ...                 ...           ...
# 11908463 2021-01-31 23:25:40            89 2021-01-31 23:40:10            71
# 11908464 2021-01-31 23:29:31           182 2021-01-31 23:47:44           167
# 11908465 2021-01-31 23:49:32           167 2021-02-01 00:04:36           169
# 11908466 2021-01-31 23:09:29           188 2021-01-31 23:27:46            37
# 11908467 2021-01-31 23:28:33            37 2021-01-31 23:56:36             4
#
# [11908468 rows x 4 columns]

# %%
temp_file = file[col_names]
sortedDf = temp_file.sort_values('pickup_datetime')

# %%
print(sortedDf.iloc[13])
# Out:
# pickup_datetime     2021-01-01 00:00:06
# PULocationID                        133
# dropoff_datetime    2021-01-01 00:09:48
# DOLocationID                         89
# Name: 30087, dtype: object

# %%
import time
from datetime import datetime, timedelta

# Set the fake clock time
fake_clock = datetime(2021, 1, 1, 0, 0, 0)

# Set the interval
interval = 20

# %%
print(fake_clock)
# Out:
# 2021-01-01 00:00:00

# %%
# Upload data by pickup time

for index, row in sortedDf.iterrows():
    # Get the pickup datetime from the current row
    pickup_datetime = row['pickup_datetime']

    # Wait until the fake clock time reaches the pickup datetime
    while fake_clock < pickup_datetime:
        time.sleep(1)  # Wait for 1 second
        fake_clock += timedelta(seconds=interval)
        print("fake_clock time: ", fake_clock)

    # Create a list to store the rows to be inserted
    rows_to_insert = []

    # Iterate until the fake clock time exceeds the pickup datetime
    while fake_clock >= pickup_datetime:
        # Append the current row to the list
        rows_to_insert.append(row)

        # Get the next row (if available)
        try:
            index += 1  # Increment the index
            row = sortedDf.iloc[index]
            pickup_datetime = row['pickup_datetime']
        except IndexError:
            break

    # Update all the rows in the list into MongoDB
#     print("insert number : ", len(rows_to_insert))
    rows_dict = [r.fillna("-").to_dict() for r in rows_to_insert]
    collection.insert_many(rows_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29364\4014162616.py in <module>
#       1 # Upload data by pickup time
#       2
# ----> 3 for index, row in sortedDf.iterrows():
#       4     # Get the pickup datetime from the current row
#       5     pickup_datetime = row['pickup_datetime']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in iterrows(self)
#    1321         columns = self.columns
#    1322         klass = self._constructor_sliced
# -> 1323         for k, v in zip(self.index, self.values):
#    1324             s = klass(v, index=columns, name=k)
#    1325             yield k, s
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in values(self)
#   10890         """
#   10891         self._consolidate_inplace()
# > 10892         return self._mgr.as_array()
#   10893
#   10894     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self"])
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in as_array(self, dtype, copy, na_value)
#    1597                     arr = arr.astype(dtype, copy=False)
#    1598         else:
# -> 1599             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1600             # The underlying data was copied within _interleave
#    1601             copy = False
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _interleave(self, dtype, na_value)
#    1646                 arr = blk.get_values(dtype)
#    1647                 result[rl.indexer] = arr
# -> 1648                 itemmask[rl.indexer] = 1
#    1649             return result
#    1650
#
# KeyboardInterrupt:

# %%
# for file_name in file_name_list:
# file_name = file_name_list[0]
# file = pd.read_parquet(path + file_name)
# print('working on filename:', file_name)

num = len(sortedDf)/(8000)
res = np.array_split(sortedDf, int(num)+1)
print('Total # sub_df:', num+1)
sub_file_count = 1

for sub_file in res:
    print(datetime.now().strftime('%Y-%m-%d %H:%M:%S'), 'working on sub-file:', sub_file_count)
    sub_file.fillna("-",inplace=True)
    sub_file_dict = sub_file.to_dict(orient="records")
    collection.insert_many(sub_file_dict)
    sub_file_count += 1
# Out:
# Total # sub_df: 1489.5585
# 2023-06-05 22:35:31 working on sub-file: 1
# 2023-06-05 22:35:37 working on sub-file: 2
# 2023-06-05 22:35:39 working on sub-file: 3
# 2023-06-05 22:35:41 working on sub-file: 4
# 2023-06-05 22:35:43 working on sub-file: 5
# 2023-06-05 22:35:44 working on sub-file: 6
# 2023-06-05 22:35:45 working on sub-file: 7
# 2023-06-05 22:35:48 working on sub-file: 8
# 2023-06-05 22:35:51 working on sub-file: 9
# 2023-06-05 22:35:52 working on sub-file: 10
# 2023-06-05 22:35:54 working on sub-file: 11
# 2023-06-05 22:35:55 working on sub-file: 12
# 2023-06-05 22:35:57 working on sub-file: 13
# 2023-06-05 22:35:57 working on sub-file: 14
# 2023-06-05 22:35:58 working on sub-file: 15
return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     716
#
# ~\anaconda3\lib\site-packages\pymongo\bulk.py in execute(self, write_concern, session)
#     511                 self.execute_no_results(sock_info, generator, write_concern)
#     512         else:
# --> 513             return self.execute_command(generator, write_concern, session)
#
# ~\anaconda3\lib\site-packages\pymongo\bulk.py in execute_command(self, generator, write_concern, session)
#     389         client = self.collection.database.client
#     390         with client._tmp_session(session) as s:
# --> 391             client._retry_with_session(self.is_retryable, retryable_bulk, s, self)
#     392
#     393         if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1347             retryable and self.options.retry_writes and session and not session.in_transaction
#    1348         )
# -> 1349         return self._retry_internal(retryable, func, session, bulk)
#    1350
#    1351     @_csot.apply
#
# ~\anaconda3\lib\site-packages\pymongo\_csot.py in csot_wrapper(self, *args, **kwargs)
#     103                 with _TimeoutContext(timeout):
#     104                     return func(self, *args, **kwargs)
# --> 105         return func(self, *args, **kwargs)
#     106
#     107     return cast(F, csot_wrapper)
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1388                             raise last_error
#    1389                         retryable = False
# -> 1390                     return func(session, sock_info, retryable)
#    1391             except ServerSelectionTimeoutError:
#    1392                 if is_retrying():
#
# ~\anaconda3\lib\site-packages\pymongo\bulk.py in retryable_bulk(session, sock_info, retryable)
#     383
#     384         def retryable_bulk(session, sock_info, retryable):
# --> 385             self._execute_command(
#     386                 generator, write_concern, session, sock_info, op_id, retryable, full_result
#     387             )
#
# ~\anaconda3\lib\site-packages\pymongo\bulk.py in _execute_command(self, generator, write_concern, session, sock_info, op_id, retryable, full_result, final_write_concern)
#     336                 # Run as many ops as possible in one command.
#     337                 if write_concern.acknowledged:
# --> 338                     result, to_send = bwc.execute(cmd, ops, client)
#     339
#     340                     # Retryable writeConcernErrors halt the execution of this run.
#
# ~\anaconda3\lib\site-packages\pymongo\message.py in execute(self, cmd, docs, client)
#     840     def execute(self, cmd, docs, client):
#     841         request_id, msg, to_send = self._batch_command(cmd, docs)
# --> 842         result = self.write_command(cmd, request_id, msg, to_send)
#     843         client._process_response(result, self.session)
#     844         return result, to_send
#
# ~\anaconda3\lib\site-packages\pymongo\message.py in write_command(self, cmd, request_id, msg, docs)
#     918             start = datetime.datetime.now()
#     919         try:
# --> 920             reply = self.sock_info.write_command(request_id, msg, self.codec)
#     921             if self.publish:
#     922                 duration = (datetime.datetime.now() - start) + duration
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in write_command(self, request_id, msg, codec_options)
#     855
#     856         # Raises NotPrimaryError or OperationFailure.
# --> 857         helpers._check_command_response(result, self.max_wire_version)
#     858         return result
#     859
#
# ~\anaconda3\lib\site-packages\pymongo\helpers.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     179         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     180
# --> 181     raise OperationFailure(errmsg, code, response, max_wire_version)
#     182
#     183
#
# OperationFailure: you are over your space quota, using 514 MB of 512 MB, full error: {'ok': 0, 'errmsg': 'you are over your space quota, using 514 MB of 512 MB', 'code': 8000, 'codeName': 'AtlasError'}

# %%
# deleta
result = collection.delete_many({}) 
# Print the number of deleted documents 
print("Deleted documents:", result.deleted_count)
# Out:
# Deleted documents: 67
